# %%
### Theme: Student Performance Analysis & Prediction

# Task 1 — Data Exploration with Pandas

import pandas as pd

# Loading the dataset
df = pd.read_csv("students.csv");

print(df.columns)

# 1.Printing first 5 rows
print(df.head(5))

# 2.Printing shape and datatype of each column
print("\nShape (rows, cols):", df.shape)
print("\nDatatype of each column:\n",df.dtypes)


# 3.Printing summary statistics 
print("\nSummary Statistics:\n",df.describe())

# 4. Printing the count of students who passed and who failed.
'''
counts = df["passed"].value_counts()

print(f"Passed: {counts.get(1, 0)}")
print(f"Failed: {counts.get(0, 0)}")
'''

#print(f"\nThe count of students who passed:{count}")


# 5. Computing and print the average score per subject

# 6. Finding and printing the student with the highest overall average across all 5 subjects.

# Task 2 — Data Visualization with Matplotlib

# Task 3 — Data Visualization with Seaborn

# Task 4 — Machine Learning with scikit-learn
# Out:
# Index(['name,math,science,english,history,pe,attendance_pct,study_hours_per_day,passed'], dtype='str')
#   name,math,science,english,history,pe,attendance_pct,study_hours_per_day,passed
# 0                      Alice,88,92,76,80,95,92,4.5,1
# 1                        Bob,42,55,48,50,60,65,1.2,0
# 2                    Charlie,75,70,80,68,88,85,3.0,1
# 3                      Diana,95,98,91,89,97,98,6.0,1
# 4                        Eve,38,42,50,45,55,58,0.8,0
#
# Shape (rows, cols): (15, 1)
#
# Datatype of each column:
#  name,math,science,english,history,pe,attendance_pct,study_hours_per_day,passed    str
# dtype: object
#
# Summary Statistics:
#         name,math,science,english,history,pe,attendance_pct,study_hours_per_day,passed
# count                                                  15
# unique                                                 15
# top                         Alice,88,92,76,80,95,92,4.5,1
# freq                                                    1
# '\ncounts = df["passed"].value_counts()\n\nprint(f"Passed: {counts.get(1, 0)}")\nprint(f"Failed: {counts.get(0, 0)}")\n'
